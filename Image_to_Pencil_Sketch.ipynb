# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
image = cv2.imread('/content/pic.png')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F97CC369250>

# %%
#grey scale image
#black and  white photo
grey_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY) 
cv2_imshow(grey_image)
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F97CC287E50>

# %%
#inverted scale image
#negative image
inverted_image = cv2.bitwise_not(grey_image)  
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F97CC297390>

# %%
#image smoothing
image_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(image_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F97CC29A490>

# %%
#pencil sketch
#mixing grey scale image with inverted image
def pencil_sketch(x, y):
    return cv2.divide(x, 255 - y, scale=256)
pencil_sketch=pencil_sketch(grey_image,image_smoothing)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F97CC29F050>

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F97CC295550>
# <PIL.Image.Image image mode=L size=275x183 at 0x7F97CC295590>
